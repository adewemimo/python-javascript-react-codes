# %%
! ls
# Out:
# Pipfile        Pipfile.lock   Untitled.ipynb cars_ds        cheatsheet     data           start.py

# %%
! pwd
# Out:
# /Users/casoetan/Sites/Projects/kw-pythonista/datascience

# %%
! ls ./data
# Out:
# 46100048-eng.zip      46100048_MetaData.csv cars.csv              house_d_ca.csv        ontarioproperties.zip

# %%
import pandas as pd

# %%
df = pd.read_csv('./data/cars.csv')

# %%
df.head(5)
# Out:
#    Dimensions.Height  Dimensions.Length  Dimensions.Width  \
# 0                140                143               202
# 1                140                143               202
# 2                140                143               202
# 3                140                143               202
# 4                140                143               202
#
#   Engine Information.Driveline                Engine Information.Engine Type  \
# 0              All-wheel drive          Audi 3.2L 6 cylinder 250hp 236ft-lbs
# 1            Front-wheel drive  Audi 2.0L 4 cylinder 200 hp 207 ft-lbs Turbo
# 2            Front-wheel drive  Audi 2.0L 4 cylinder 200 hp 207 ft-lbs Turbo
# 3              All-wheel drive  Audi 2.0L 4 cylinder 200 hp 207 ft-lbs Turbo
# 4              All-wheel drive  Audi 2.0L 4 cylinder 200 hp 207 ft-lbs Turbo
#
#    Engine Information.Hybrid  Engine Information.Number of Forward Gears  \
# 0                       True                                           6
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5076 entries, 0 to 5075
# Data columns (total 18 columns):
#  #   Column                                           Non-Null Count  Dtype
# ---  ------                                           --------------  -----
#  0   Dimensions.Height                                5076 non-null   int64
#  1   Dimensions.Length                                5076 non-null   int64
#  2   Dimensions.Width                                 5076 non-null   int64
#  3   Engine Information.Driveline                     5076 non-null   object
#  4   Engine Information.Engine Type                   5076 non-null   object
#  5   Engine Information.Hybrid                        5076 non-null   bool
#  6   Engine Information.Number of Forward Gears       5076 non-null   int64
#  7   Engine Information.Transmission                  5076 non-null   object
#  8   Fuel Information.City mpg                        5076 non-null   int64
# ...

# %%
df['Dimensions.Height'].dtypes
# Out:
# dtype('int64')

# %%
s = pd.Series([1, 'Seun', 'Toronto'])

# %%
s
# Out:
# 0          1
# 1       Seun
# 2    Toronto
# dtype: object

# %%
df.memory_usage()
# Out:
# Index                                                128
# Dimensions.Height                                  40608
# Dimensions.Length                                  40608
# Dimensions.Width                                   40608
# Engine Information.Driveline                       40608
# Engine Information.Engine Type                     40608
# Engine Information.Hybrid                           5076
# Engine Information.Number of Forward Gears         40608
# Engine Information.Transmission                    40608
# Fuel Information.City mpg                          40608
# Fuel Information.Fuel Type                         40608
# Fuel Information.Highway mpg                       40608
# Identification.Classification                      40608
# Identification.ID                                  40608
# Identification.Make                                40608
# Identification.Model Year                          40608
# ...

# %%
df.dtypes
# Out:
# Dimensions.Height                                   int64
# Dimensions.Length                                   int64
# Dimensions.Width                                    int64
# Engine Information.Driveline                       object
# Engine Information.Engine Type                     object
# Engine Information.Hybrid                            bool
# Engine Information.Number of Forward Gears          int64
# Engine Information.Transmission                    object
# Fuel Information.City mpg                           int64
# Fuel Information.Fuel Type                         object
# Fuel Information.Highway mpg                        int64
# Identification.Classification                      object
# Identification.ID                                  object
# Identification.Make                                object
# Identification.Model Year                          object
# Identification.Year                                 int64
# ...

# %%
df.describe()
# Out:
#        Dimensions.Height  Dimensions.Length  Dimensions.Width  \
# count        5076.000000        5076.000000       5076.000000
# mean          145.632191         127.825847        144.012411
# std            62.125026          77.358295         79.925899
# min             1.000000           2.000000          1.000000
# 25%           104.000000          60.000000         62.000000
# 50%           152.000000         128.000000        158.000000
# 75%           193.000000         198.000000        219.000000
# max           255.000000         255.000000        254.000000
#
#        Engine Information.Number of Forward Gears  Fuel Information.City mpg  \
# count                                 5076.000000                5076.000000
# mean                                     5.519110                  17.275808
# std                                      0.845637                   4.479485
# min                                      4.000000                   8.000000
# ...

# %%
df['Identification.Year'].head()
# Out:
# 0    2009
# 1    2009
# 2    2009
# 3    2009
# 4    2009
# Name: Identification.Year, dtype: int64

# %%
df2 = df[['Engine Information.Number of Forward Gears', 'Identification.Year']]

# %%
df2
# Out:
#       Engine Information.Number of Forward Gears  Identification.Year
# 0                                              6                 2009
# 1                                              6                 2009
# 2                                              6                 2009
# 3                                              6                 2009
# 4                                              6                 2009
# ...                                          ...                  ...
# 5071                                           5                 2012
# 5072                                           6                 2012
# 5073                                           6                 2012
# 5074                                           6                 2012
# 5075                                           6                 2012
#
# [5076 rows x 2 columns]

# %%
len(df[df['Identification.Year'] < 2010])
# Out:
# 49

# %%
len(df[(df['Identification.Year'] < 2010) & (df['Fuel Information.City mpg'] < 20)])
# Out:
# 31

# %%
df2.iloc[4]
# Out:
# Engine Information.Number of Forward Gears       6
# Identification.Year                           2009
# Name: 4, dtype: int64

# %%
df2.loc[4]
# Out:
# Engine Information.Number of Forward Gears       6
# Identification.Year                           2009
# Name: 4, dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
gdf = df.groupby(by=['Identification.Year'])

# %%
gdf.count()
# Out:
#                      Dimensions.Height  Dimensions.Length  Dimensions.Width  \
# Identification.Year
# 2009                                49                 49                49
# 2010                              1789               1789              1789
# 2011                              2023               2023              2023
# 2012                              1215               1215              1215
#
#                      Engine Information.Driveline  \
# Identification.Year
# 2009                                           49
# 2010                                         1789
# 2011                                         2023
# 2012                                         1215
#
#                      Engine Information.Engine Type  \
# Identification.Year
# 2009                                             49
# 2010                                           1789
# 2011                                           2023
# 2012                                           1215
# ...

# %%
len(df[df['Identification.Year'] > 2011])
# Out:
# 1215

# %%
gdf.count()
# Out:
#                      Dimensions.Height  Dimensions.Length  Dimensions.Width  \
# Identification.Year
# 2009                                49                 49                49
# 2010                              1789               1789              1789
# 2011                              2023               2023              2023
# 2012                              1215               1215              1215
#
#                      Engine Information.Driveline  \
# Identification.Year
# 2009                                           49
# 2010                                         1789
# 2011                                         2023
# 2012                                         1215
#
#                      Engine Information.Engine Type  \
# Identification.Year
# 2009                                             49
# 2010                                           1789
# 2011                                           2023
# 2012                                           1215
# ...

# %%
gdf.size()
# Out:
# Identification.Year
# 2009      49
# 2010    1789
# 2011    2023
# 2012    1215
# dtype: int64

# %%
gdf.mean()
# Out:
#                      Dimensions.Height  Dimensions.Length  Dimensions.Width  \
# Identification.Year
# 2009                        106.326531         108.857143        116.306122
# 2010                        147.011179         129.348798        144.157071
# 2011                        141.666337         131.350470        149.434998
# 2012                        151.790123         120.479835        135.888066
#
#                      Engine Information.Hybrid  \
# Identification.Year
# 2009                                      True
# 2010                                      True
# 2011                                      True
# 2012                                      True
#
#                      Engine Information.Number of Forward Gears  \
# Identification.Year
# 2009                                                   5.591837
# 2010                                                   5.381778
# 2011                                                   5.520020
# ...

# %%
df['Engine Information.Number of Forward Gears'].unique()
# Out:
# array([6, 5, 4, 7, 8])

# %%
df[df['Engine Information.Number of Forward Gears'] == 8]
# Out:
#       Dimensions.Height  Dimensions.Length  Dimensions.Width  \
# 128                 147                 95               248
# 130                 147                 95               214
# 145                 156                 95               248
# 146                 156                 95               214
# 250                  13                 24               156
# ...                 ...                ...               ...
# 4960                183                 40                67
# 4961                183                 40                67
# 4963                183                 40                67
# 4964                183                 40                67
# 5051                241                199               134
#
#      Engine Information.Driveline  \
# 128               All-wheel drive
# 130               All-wheel drive
# 145               All-wheel drive
# 146               All-wheel drive
# 250              Rear-wheel drive
# ...

# %%
mdf = df.groupby(by=['Identification.Make'])

# %%
mdf.count()
# Out:
#                      Dimensions.Height  Dimensions.Length  Dimensions.Width  \
# Identification.Make
# AMG                                 10                 10                10
# Acura                               33                 33                33
# Aston Martin                        43                 43                43
# Audi                                87                 87                87
# BMW                                133                133               133
# BMW Motorrad                        58                 58                58
# Bentley                             18                 18                18
# Buick                               71                 71                71
# Cadillac                           200                200               200
# Chevrolet                          626                626               626
# Chrysler                            30                 30                30
# ...

# %%
fig, ax = plt.subplots(figsize=(15,7))
mdf.count()['Engine Information.Number of Forward Gears'].plot(ax=ax)

# %%
fig, ax = plt.subplots(figsize=(15,7))
gdf.count()['Fuel Information.Highway mpg'].plot(ax=ax)

# %%
fig, ax = plt.subplots(figsize=(15,7))
df.plot(ax=ax)

# %%
df2 = df[['Engine Information.Number of Forward Gears', 'Fuel Information.City mpg']]
fig, ax = plt.subplots(figsize=(15,7))
ax.scatter(x=df['Fuel Information.City mpg'], y=df['Engine Information.Number of Forward Gears'])
# df2.plot(ax=ax)
# df2.plot(x ='Fuel Information.City mpg', y='Engine Information.Number of Forward Gears', kind = 'scatter', figsize=(15,7))

# %%
# %matplotlib inline
fig, ax = plt.subplots(figsize=(15,7))
ax.bar(df['Fuel Information.City mpg'], df['Engine Information.Number of Forward Gears'])
# Out:
# <BarContainer object of 5076 artists>
