# %%
import pandas as pd

# %%
cars_df = pd.read_csv('./data/cars.csv')

# %%
cars_df.columns
# Out:
# Index(['Dimensions.Height', 'Dimensions.Length', 'Dimensions.Width',
#        'Engine Information.Driveline', 'Engine Information.Engine Type',
#        'Engine Information.Hybrid',
#        'Engine Information.Number of Forward Gears',
#        'Engine Information.Transmission', 'Fuel Information.City mpg',
#        'Fuel Information.Fuel Type', 'Fuel Information.Highway mpg',
#        'Identification.Classification', 'Identification.ID',
#        'Identification.Make', 'Identification.Model Year',
#        'Identification.Year',
#        'Engine Information.Engine Statistics.Horsepower',
#        'Engine Information.Engine Statistics.Torque'],
#       dtype='object')

# %%
cars_df.shape
# Out:
# (5076, 18)

# %%
cars_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5076 entries, 0 to 5075
# Data columns (total 18 columns):
# Dimensions.Height                                  5076 non-null int64
# Dimensions.Length                                  5076 non-null int64
# Dimensions.Width                                   5076 non-null int64
# Engine Information.Driveline                       5076 non-null object
# Engine Information.Engine Type                     5076 non-null object
# Engine Information.Hybrid                          5076 non-null bool
# Engine Information.Number of Forward Gears         5076 non-null int64
# Engine Information.Transmission                    5076 non-null object
# Fuel Information.City mpg                          5076 non-null int64
# Fuel Information.Fuel Type                         5076 non-null object
# Fuel Information.Highway mpg                       5076 non-null int64
# Identification.Classification                      5076 non-null object
# ...

# %%
cars_df.head()
# Out:
#    Dimensions.Height  Dimensions.Length  Dimensions.Width  \
# 0                140                143               202
# 1                140                143               202
# 2                140                143               202
# 3                140                143               202
# 4                140                143               202
#
#   Engine Information.Driveline                Engine Information.Engine Type  \
# 0              All-wheel drive          Audi 3.2L 6 cylinder 250hp 236ft-lbs
# 1            Front-wheel drive  Audi 2.0L 4 cylinder 200 hp 207 ft-lbs Turbo
# 2            Front-wheel drive  Audi 2.0L 4 cylinder 200 hp 207 ft-lbs Turbo
# 3              All-wheel drive  Audi 2.0L 4 cylinder 200 hp 207 ft-lbs Turbo
# 4              All-wheel drive  Audi 2.0L 4 cylinder 200 hp 207 ft-lbs Turbo
#
#    Engine Information.Hybrid  Engine Information.Number of Forward Gears  \
# 0                       True                                           6
# ...

# %%
cars_df.tail()
# Out:
#       Dimensions.Height  Dimensions.Length  Dimensions.Width  \
# 5071                 13                253               201
# 5072                141                249               108
# 5073                160                249               108
# 5074                200                210               110
# 5075                200                 94               110
#
#      Engine Information.Driveline  \
# 5071            Front-wheel drive
# 5072              All-wheel drive
# 5073              All-wheel drive
# 5074             Rear-wheel drive
# 5075             Rear-wheel drive
#
#                       Engine Information.Engine Type  \
# 5071         Honda 3.5L 6 Cylinder 250 hp 253 ft-lbs
# 5072  Lamborghini 5.2L 10 cylinder 552 hp 398 ft-lbs
# 5073  Lamborghini 5.2L 10 cylinder 552 hp 398 ft-lbs
# 5074      BMW 3.0L 6 cylinder 315hp 330 ft-lbs Turbo
# 5075      BMW 3.0L 6 cylinder 315hp 330 ft-lbs Turbo
#
# ...

# %%
cars_df.describe()
# Out:
#        Dimensions.Height  Dimensions.Length  Dimensions.Width  \
# count        5076.000000        5076.000000       5076.000000
# mean          145.632191         127.825847        144.012411
# std            62.125026          77.358295         79.925899
# min             1.000000           2.000000          1.000000
# 25%           104.000000          60.000000         62.000000
# 50%           152.000000         128.000000        158.000000
# 75%           193.000000         198.000000        219.000000
# max           255.000000         255.000000        254.000000
#
#        Engine Information.Number of Forward Gears  Fuel Information.City mpg  \
# count                                 5076.000000                5076.000000
# mean                                     5.519110                  17.275808
# std                                      0.845637                   4.479485
# min                                      4.000000                   8.000000
# ...

# %%
cars_df_sub = cars_df[['Identification.Make', 'Identification.Year', 'Engine Information.Number of Forward Gears', 'Engine Information.Engine Statistics.Horsepower', 'Identification.Classification']]

# %%
cars_df_sub.head()
# Out:
#   Identification.Make  Identification.Year  \
# 0                Audi                 2009
# 1                Audi                 2009
# 2                Audi                 2009
# 3                Audi                 2009
# 4                Audi                 2009
#
#    Engine Information.Number of Forward Gears  \
# 0                                           6
# 1                                           6
# 2                                           6
# 3                                           6
# 4                                           6
#
#    Engine Information.Engine Statistics.Horsepower  \
# 0                                              250
# 1                                              200
# 2                                              200
# 3                                              200
# 4                                              200
#
#   Identification.Classification
# 0        Automatic transmission
# 1        Automatic transmission
# ...

# %%
cars_df_sub.tail()
# Out:
#      Identification.Make  Identification.Year  \
# 5071               Honda                 2012
# 5072         Lamborghini                 2012
# 5073         Lamborghini                 2012
# 5074                 BMW                 2012
# 5075                 BMW                 2012
#
#       Engine Information.Number of Forward Gears  \
# 5071                                           5
# 5072                                           6
# 5073                                           6
# 5074                                           6
# 5075                                           6
#
#       Engine Information.Engine Statistics.Horsepower  \
# 5071                                              250
# 5072                                              552
# 5073                                              552
# 5074                                              315
# 5075                                              315
#
#      Identification.Classification
# ...

# %%
len(cars_df_sub[cars_df_sub['Identification.Make'] == 'Lamborghini'])
# Out:
# 5

# %%
cars_df_sub[cars_df_sub['Identification.Make'] == 'Lamborghini']
# Out:
#      Identification.Make  Identification.Year  \
# 439          Lamborghini                 2010
# 449          Lamborghini                 2011
# 450          Lamborghini                 2011
# 5072         Lamborghini                 2012
# 5073         Lamborghini                 2012
#
#       Engine Information.Number of Forward Gears  \
# 439                                            6
# 449                                            6
# 450                                            6
# 5072                                           6
# 5073                                           6
#
#       Engine Information.Engine Statistics.Horsepower  \
# 439                                               550
# 449                                               560
# 450                                               560
# 5072                                              552
# 5073                                              552
#
#      Identification.Classification
# ...

# %%
len(cars_df_sub[cars_df_sub['Identification.Make'] == 'Honda'])
# Out:
# 200

# %%
len(cars_df_sub[(cars_df_sub['Identification.Make'] == 'Honda') & (cars_df_sub['Engine Information.Engine Statistics.Horsepower']== 250)])
# Out:
# 26

# %%
cars_df_sub[(cars_df_sub['Identification.Make'] == 'Honda') & (cars_df_sub['Engine Information.Engine Statistics.Horsepower']== 250)]
# Out:
#      Identification.Make  Identification.Year  \
# 1810               Honda                 2011
# 1811               Honda                 2011
# 1812               Honda                 2011
# 1813               Honda                 2011
# 1814               Honda                 2011
# 1815               Honda                 2011
# 1816               Honda                 2011
# 1817               Honda                 2011
# 2223               Honda                 2010
# 2224               Honda                 2011
# 2225               Honda                 2010
# 2226               Honda                 2010
# 2227               Honda                 2010
# 2228               Honda                 2010
# 2229               Honda                 2010
# 2999               Honda                 2011
# 3000               Honda                 2011
# 3001               Honda                 2011
# 3002               Honda                 2010
# ...

# %%
len(cars_df_sub[(cars_df_sub['Identification.Make'] == 'Toyota') & (cars_df_sub['Engine Information.Number of Forward Gears'] == 4)] )
# Out:
# 44

# %%
total_df_4g = cars_df_sub[(cars_df_sub['Identification.Make'] == 'Toyota') & (cars_df_sub['Engine Information.Number of Forward Gears'] == 4)]

# %%
total_df_4g
# Out:
#      Identification.Make  Identification.Year  \
# 94                Toyota                 2010
# 246               Toyota                 2011
# 247               Toyota                 2011
# 249               Toyota                 2011
# 292               Toyota                 2010
# 294               Toyota                 2010
# 295               Toyota                 2010
# 296               Toyota                 2010
# 347               Toyota                 2011
# 350               Toyota                 2011
# 365               Toyota                 2010
# 368               Toyota                 2010
# 485               Toyota                 2011
# 486               Toyota                 2011
# 489               Toyota                 2011
# 490               Toyota                 2011
# 493               Toyota                 2011
# 494               Toyota                 2011
# 1196              Toyota                 2010
# ...

# %%
total_df_4g.head()
# Out:
#     Identification.Make  Identification.Year  \
# 94               Toyota                 2010
# 246              Toyota                 2011
# 247              Toyota                 2011
# 249              Toyota                 2011
# 292              Toyota                 2010
#
#      Engine Information.Number of Forward Gears  \
# 94                                            4
# 246                                           4
# 247                                           4
# 249                                           4
# 292                                           4
#
#      Engine Information.Engine Statistics.Horsepower  \
# 94                                               157
# 246                                              132
# 247                                              132
# 249                                              132
# 292                                              132
#
#     Identification.Classification
# 94         Automatic transmission
# ...

# %%
toyota_df_6g_plus = cars_df_sub[(cars_df_sub['Identification.Make'] == 'Toyota') & (cars_df_sub['Engine Information.Number of Forward Gears'] >= 6)]

# %%
len(toyota_df_6g_plus)
# Out:
# 170

# %%
toyota_df_6g_plus.to_csv('./data/toyota_df_6g_plus.csv')

# %%
grouped_cars_sub = cars_df_sub.groupby(by='Identification.Year')

# %%
grouped_cars_sub.count()
# Out:
#                      Identification.Make  \
# Identification.Year
# 2009                                  49
# 2010                                1789
# 2011                                2023
# 2012                                1215
#
#                      Engine Information.Number of Forward Gears  \
# Identification.Year
# 2009                                                         49
# 2010                                                       1789
# 2011                                                       2023
# 2012                                                       1215
#
#                      Engine Information.Engine Statistics.Horsepower  \
# Identification.Year
# 2009                                                              49
# 2010                                                            1789
# 2011                                                            2023
# 2012                                                            1215
#
# ...

# %%
grouped_cars_sub2 = cars_df_sub.groupby(by='Identification.Make')

# %%
grouped_cars_sub2.count()
# Out:
#                      Identification.Year  \
# Identification.Make
# AMG                                   10
# Acura                                 33
# Aston Martin                          43
# Audi                                  87
# BMW                                  133
# BMW Motorrad                          58
# Bentley                               18
# Buick                                 71
# Cadillac                             200
# Chevrolet                            626
# Chrysler                              30
# Chrysler Group LLC                     6
# Dodge                                260
# Ferrari                                1
# Ford                                 603
# GMC                                  368
# Grand Cherokee                        48
# Honda                                200
# Hyundai                              188
# Infiniti                              85
# Jaguar                                44
# ...

# %%
import matplotlib.pyplot as plt

# %%
fig, ax = plt.subplots(figsize=(18,10))
ax.bar(cars_df['Fuel Information.City mpg'], cars_df['Engine Information.Number of Forward Gears'])
# Out:
# <BarContainer object of 5076 artists>

# %%
cars_df['Identification.Year'].plot('hist' ) # can be written as cars_df['Identification.Year'].plot(kind = 'hist')

# %%
cars_df['Identification.Year'].plot(kind = 'hist', rot=70, logx=True, logy=True) # Please notice this is for practice purposes for when min an max values for the x and y are so far apart and you need to rescale the graph.

# %%
cars_df_sub.dropna() # to find missing values
# Out:
#      Identification.Make  Identification.Year  \
# 0                   Audi                 2009
# 1                   Audi                 2009
# 2                   Audi                 2009
# 3                   Audi                 2009
# 4                   Audi                 2009
# 5                   Audi                 2009
# 6                   Audi                 2009
# 7                   Audi                 2009
# 8                   Audi                 2009
# 9                   Audi                 2009
# 10                  Audi                 2009
# 11                  Audi                 2009
# 12                 Acura                 2012
# 13                 Acura                 2012
# 14                   BMW                 2010
# 15                   BMW                 2011
# 16                   BMW                 2010
# 17                   BMW                 2011
# 18             Chevrolet                 2012
# ...

# %%
cars_df['Identification.Year'].value_counts(dropna = False) # perform frequency count on column and give information on missing values using dropna to be False. this can be done for all columns too
# Out:
# 2011    2023
# 2010    1789
# 2012    1215
# 2009      49
# Name: Identification.Year, dtype: int64
