# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
cars2_df = pd.read_csv('./data/cars.csv')

# %%
cars2_df.columns
# Out:
# Index(['Dimensions.Height', 'Dimensions.Length', 'Dimensions.Width',
#        'Engine Information.Driveline', 'Engine Information.Engine Type',
#        'Engine Information.Hybrid',
#        'Engine Information.Number of Forward Gears',
#        'Engine Information.Transmission', 'Fuel Information.City mpg',
#        'Fuel Information.Fuel Type', 'Fuel Information.Highway mpg',
#        'Identification.Classification', 'Identification.ID',
#        'Identification.Make', 'Identification.Model Year',
#        'Identification.Year',
#        'Engine Information.Engine Statistics.Horsepower',
#        'Engine Information.Engine Statistics.Torque'],
#       dtype='object')

# %%
cars2_df.shape
# Out:
# (5076, 18)

# %%
cars2_df.index
# Out:
# RangeIndex(start=0, stop=5076, step=1)

# %%
cars2_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5076 entries, 0 to 5075
# Data columns (total 18 columns):
# Dimensions.Height                                  5076 non-null int64
# Dimensions.Length                                  5076 non-null int64
# Dimensions.Width                                   5076 non-null int64
# Engine Information.Driveline                       5076 non-null object
# Engine Information.Engine Type                     5076 non-null object
# Engine Information.Hybrid                          5076 non-null bool
# Engine Information.Number of Forward Gears         5076 non-null int64
# Engine Information.Transmission                    5076 non-null object
# Fuel Information.City mpg                          5076 non-null int64
# Fuel Information.Fuel Type                         5076 non-null object
# Fuel Information.Highway mpg                       5076 non-null int64
# Identification.Classification                      5076 non-null object
# ...

# %%
cars2_df.head()
# Out:
#    Dimensions.Height  Dimensions.Length  Dimensions.Width  \
# 0                140                143               202
# 1                140                143               202
# 2                140                143               202
# 3                140                143               202
# 4                140                143               202
#
#   Engine Information.Driveline                Engine Information.Engine Type  \
# 0              All-wheel drive          Audi 3.2L 6 cylinder 250hp 236ft-lbs
# 1            Front-wheel drive  Audi 2.0L 4 cylinder 200 hp 207 ft-lbs Turbo
# 2            Front-wheel drive  Audi 2.0L 4 cylinder 200 hp 207 ft-lbs Turbo
# 3              All-wheel drive  Audi 2.0L 4 cylinder 200 hp 207 ft-lbs Turbo
# 4              All-wheel drive  Audi 2.0L 4 cylinder 200 hp 207 ft-lbs Turbo
#
#    Engine Information.Hybrid  Engine Information.Number of Forward Gears  \
# 0                       True                                           6
# ...

# %%
cars2_df.tail()
# Out:
#       Dimensions.Height  Dimensions.Length  Dimensions.Width  \
# 5071                 13                253               201
# 5072                141                249               108
# 5073                160                249               108
# 5074                200                210               110
# 5075                200                 94               110
#
#      Engine Information.Driveline  \
# 5071            Front-wheel drive
# 5072              All-wheel drive
# 5073              All-wheel drive
# 5074             Rear-wheel drive
# 5075             Rear-wheel drive
#
#                       Engine Information.Engine Type  \
# 5071         Honda 3.5L 6 Cylinder 250 hp 253 ft-lbs
# 5072  Lamborghini 5.2L 10 cylinder 552 hp 398 ft-lbs
# 5073  Lamborghini 5.2L 10 cylinder 552 hp 398 ft-lbs
# 5074      BMW 3.0L 6 cylinder 315hp 330 ft-lbs Turbo
# 5075      BMW 3.0L 6 cylinder 315hp 330 ft-lbs Turbo
#
# ...

# %%
cars2_df_audi= cars2_df[cars2_df['Identification.Make'] == 'Audi']

# %%
cars2_df_audi.shape
# Out:
# (87, 18)

# %%
cars2_df_audi.head()
# Out:
#    Dimensions.Height  Dimensions.Length  Dimensions.Width  \
# 0                140                143               202
# 1                140                143               202
# 2                140                143               202
# 3                140                143               202
# 4                140                143               202
#
#   Engine Information.Driveline                Engine Information.Engine Type  \
# 0              All-wheel drive          Audi 3.2L 6 cylinder 250hp 236ft-lbs
# 1            Front-wheel drive  Audi 2.0L 4 cylinder 200 hp 207 ft-lbs Turbo
# 2            Front-wheel drive  Audi 2.0L 4 cylinder 200 hp 207 ft-lbs Turbo
# 3              All-wheel drive  Audi 2.0L 4 cylinder 200 hp 207 ft-lbs Turbo
# 4              All-wheel drive  Audi 2.0L 4 cylinder 200 hp 207 ft-lbs Turbo
#
#    Engine Information.Hybrid  Engine Information.Number of Forward Gears  \
# 0                       True                                           6
# ...

# %%
cars2_df_audi.tail()
# Out:
#       Dimensions.Height  Dimensions.Length  Dimensions.Width  \
# 4501                103                 17               228
# 4502                191                147                63
# 4503                180                 17                63
# 4504                191                147                63
# 4505                 62                102                50
#
#      Engine Information.Driveline  \
# 4501              All-wheel drive
# 4502              All-wheel drive
# 4503              All-wheel drive
# 4504              All-wheel drive
# 4505              All-wheel drive
#
#                     Engine Information.Engine Type  Engine Information.Hybrid  \
# 4501  Audi 2.0L 4 cylinder 211 hp 258 ft-lbs Turbo                       True
# 4502        Audi 4.2L 8 Cylinder 372 hp 328 ft-lbs                       True
# 4503        Audi 4.2L 8 Cylinder 372 hp 328 ft-lbs                       True
# ...

# %%
cars2_df_bmw =cars2_df[cars2_df['Identification.Make'] == 'BMW']

# %%
cars2_df_bmw.shape
# Out:
# (133, 18)

# %%
cars2_df_audibmw =cars2_df[(cars2_df['Identification.Make'] == 'BMW') | (cars2_df['Identification.Make'] == 'Audi')]

# %%
cars2_df_audibmw.shape
# Out:
# (220, 18)

# %%
cars2_df_audibmw_concated = pd.concat([cars2_df_bmw, cars2_df_audi])

# %%
cars2_df_audibmw_concated.shape
# Out:
# (220, 18)

# %%
cars2_df_audibmw_concated.head()
# Out:
#      Dimensions.Height  Dimensions.Length  Dimensions.Width  \
# 14                 226                243               201
# 15                 226                243               201
# 16                 148                 12               191
# 17                 148                 12               191
# 522                132                  9               211
#
#     Engine Information.Driveline               Engine Information.Engine Type  \
# 14               All-wheel drive   BMW 4.4L 8 cylinder 555hp 500 ft-lbs Turbo
# 15               All-wheel drive   BMW 4.4L 8 cylinder 555hp 500 ft-lbs Turbo
# 16               All-wheel drive   BMW 4.4L 8 cylinder 555hp 500 ft-lbs Turbo
# 17               All-wheel drive   BMW 4.4L 8 cylinder 555hp 500 ft-lbs Turbo
# 522             Rear-wheel drive  BMW 3.0L 6 cylinder 300 hp 300 ft-lbs Turbo
#
#      Engine Information.Hybrid  Engine Information.Number of Forward Gears  \
# ...

# %%
cars2_df_audibmw.head()
# Out:
#    Dimensions.Height  Dimensions.Length  Dimensions.Width  \
# 0                140                143               202
# 1                140                143               202
# 2                140                143               202
# 3                140                143               202
# 4                140                143               202
#
#   Engine Information.Driveline                Engine Information.Engine Type  \
# 0              All-wheel drive          Audi 3.2L 6 cylinder 250hp 236ft-lbs
# 1            Front-wheel drive  Audi 2.0L 4 cylinder 200 hp 207 ft-lbs Turbo
# 2            Front-wheel drive  Audi 2.0L 4 cylinder 200 hp 207 ft-lbs Turbo
# 3              All-wheel drive  Audi 2.0L 4 cylinder 200 hp 207 ft-lbs Turbo
# 4              All-wheel drive  Audi 2.0L 4 cylinder 200 hp 207 ft-lbs Turbo
#
#    Engine Information.Hybrid  Engine Information.Number of Forward Gears  \
# 0                       True                                           6
# ...

# %%
len(cars2_df_bmw)
# Out:
# 133

# %%
len(cars2_df_bmw[cars2_df_bmw['Engine Information.Driveline']== 'All-wheel drive'])
# Out:
# 49

# %%
cars2_df_bmw_allwheel = cars2_df_bmw[cars2_df_bmw['Engine Information.Driveline']== 'All-wheel drive']

# %%
cars2_df_bmw_allwheel.head(10)
# Out:
#       Dimensions.Height  Dimensions.Length  Dimensions.Width  \
# 14                  226                243               201
# 15                  226                243               201
# 16                  148                 12               191
# 17                  148                 12               191
# 1309                114                247               247
# 1315                114                247               247
# 1332                114                 12               247
# 1339                114                 12               247
# 1443                144                174                24
# 1447                144                174                24
#
#      Engine Information.Driveline  \
# 14                All-wheel drive
# 15                All-wheel drive
# 16                All-wheel drive
# 17                All-wheel drive
# 1309              All-wheel drive
# 1315              All-wheel drive
# 1332              All-wheel drive
# ...

# %%
cars2_df_bmw['Engine Information.Engine Statistics.Torque'].plot(kind = 'hist')

# %%
grouped_cars_df_bmw = cars2_df_bmw.groupby('Engine Information.Driveline', as_index=False).count()

# %%
print(grouped_cars_df_bmw)
# Out:
#   Engine Information.Driveline  Dimensions.Height  Dimensions.Length  \
# 0              All-wheel drive                 49                 49
# 1             Rear-wheel drive                 84                 84
#
#    Dimensions.Width  Engine Information.Engine Type  \
# 0                49                              49
# 1                84                              84
#
#    Engine Information.Hybrid  Engine Information.Number of Forward Gears  \
# 0                         49                                          49
# 1                         84                                          84
#
#    Engine Information.Transmission  Fuel Information.City mpg  \
# 0                               49                         49
# 1                               84                         84
#
#    Fuel Information.Fuel Type  Fuel Information.Highway mpg  \
# 0                          49                            49
# ...

# %%
plt.bar(grouped_cars_df_bmw['Engine Information.Driveline'], grouped_cars_df_bmw['Identification.Make'])
# Out:
# <BarContainer object of 2 artists>

# %%
grouped_cars_df_bmw.all()
# Out:
# Engine Information.Driveline                       True
# Dimensions.Height                                  True
# Dimensions.Length                                  True
# Dimensions.Width                                   True
# Engine Information.Engine Type                     True
# Engine Information.Hybrid                          True
# Engine Information.Number of Forward Gears         True
# Engine Information.Transmission                    True
# Fuel Information.City mpg                          True
# Fuel Information.Fuel Type                         True
# Fuel Information.Highway mpg                       True
# Identification.Classification                      True
# Identification.ID                                  True
# Identification.Make                                True
# Identification.Model Year                          True
# Identification.Year                                True
# Engine Information.Engine Statistics.Horsepower    True
# ...

# %%
grouped_cars_df_bmw.shape
# Out:
# (2, 18)
